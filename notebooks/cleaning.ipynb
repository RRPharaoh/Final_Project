# %%
# import of libraries
import numpy as np
import pandas as pd

# %%
# first four season of overwatch 2 data, devided by charaacter and rank
s1_data = pd.read_csv('../data/ow2_season_01_2023-05-06.csv')
s2_data = pd.read_csv('../data/ow2_season_02_2023-05-06.csv')
s3_data = pd.read_csv('../data/ow2_season_03_2023-05-06.csv')
s4_data = pd.read_csv('../data/ow2_season_04_2023-06-27.csv')

# %%
s1_data.head()
# Out:
#   Hero Skill Tier  KDA Ratio  Pick Rate, %  Win Rate, %  Eliminations / 10min  \
# 0  Ana        All       3.77          8.37        52.19                  8.86
# 1  Ana     Bronze       3.43          5.90        48.67                  7.89
# 2  Ana     Silver       3.30          5.94        43.95                  7.88
# 3  Ana       Gold       3.45          6.10        49.55                  8.39
# 4  Ana   Platinum       3.76         10.20        52.73                  8.57
#
#    Objective Kills / 10min  Objective Time / 10min  Damage / 10min  \
# 0                     4.06                      67            2400
# 1                     3.89                      64            2234
# 2                     3.74                      65            2258
# 3                     4.07                      64            2307
# 4                     3.99                      63            2321
#
#    Healing / 10min  Deaths / 10min  Scoped Accuracy, %  \
# ...

# %% [markdown]
# Overwatch is a game with a large roster of characters with unique abilities,
# While having as much data as possible is ideal, many of these stats are less significant, and will convolute the data.
# To keep things simple, I' have eliminated all unique abilities, and kept only the universals and main stats for our datasets.
# I have made the exception for scoped accuracy, as I feel this is  significant identifier of skill, even though it falls outside of universal stats, since it only applies to 3 characters

# %%
s1_data.columns
# Out:
# Index(['Hero', 'Skill Tier', 'KDA Ratio', 'Pick Rate, %', 'Win Rate, %',
#        'Eliminations / 10min', 'Objective Kills / 10min',
#        'Objective Time / 10min', 'Damage / 10min', 'Healing / 10min',
#        ...
#        'Jagged Blade Accuracy, %', 'Carnage Kills / 10min', 'Wound Uptime, %',
#        'Rampage Kills / 10min', 'Focusing Beam Accuracy, %',
#        'Focusing Beam Kills / 10min', 'Sticky Bomb Accuracy, %',
#        'Sticky Bomb Kills / 10min', 'Duplicate Kills / 10min', 'Role'],
#       dtype='object', length=126)

# %%
print(s1_data.columns.tolist())
# Out:
# ['Hero', 'Skill Tier', 'KDA Ratio', 'Pick Rate, %', 'Win Rate, %', 'Eliminations / 10min', 'Objective Kills / 10min', 'Objective Time / 10min', 'Damage / 10min', 'Healing / 10min', 'Deaths / 10min', 'Scoped Accuracy, %', 'Biotic Grenade Kills / 10min', 'Enemies Slept / 10min', 'Healing Amplified / 10min', 'Nano Boost Assists / 10min', 'Blaster Kills / 10min', 'Damage Amplified / 10min', 'Players Resurrected / 10min', 'Final Blows / 10min', 'Solo Kills / 10min', 'Weapon Accuracy, %', 'Crit Accuracy, %', 'Deadeye Kills / 10min', 'Magnetic Grenade Attaches', 'Magnetic Grenade Kills / 10min', 'Swift Strike Resets / 10min', 'Damage Reflected / 10min', 'Ultimates Reflected / 10min', 'Dragonblade Kills / 10min', 'Kunai Kills / 10min', 'Effects Cleansed / 10min', 'Kitsune Rush Assists / 10min', 'Secondary Accuracy, %', 'Biotic Orb Kills / 10min', 'Ally Coalescence Efficiency, %', 'Enemy Coalescence Efficiency, %', 'Coalescence Kills / 10min', 'Objective Contest Time / 10min', 'Charge Kills /
# ...

# %%
columns_to_drop = ['Biotic Grenade Kills / 10min', 'Enemies Slept / 10min', 'Healing Amplified / 10min', 'Nano Boost Assists / 10min', 'Blaster Kills / 10min', 'Damage Amplified / 10min', 'Players Resurrected / 10min', 'Final Blows / 10min', 'Solo Kills / 10min', 'Weapon Accuracy, %', 'Crit Accuracy, %', 'Deadeye Kills / 10min', 'Magnetic Grenade Attaches', 'Magnetic Grenade Kills / 10min', 'Swift Strike Resets / 10min', 'Damage Reflected / 10min', 'Ultimates Reflected / 10min', 'Dragonblade Kills / 10min', 'Kunai Kills / 10min', 'Effects Cleansed / 10min', 'Kitsune Rush Assists / 10min', 'Secondary Accuracy, %', 'Biotic Orb Kills / 10min', 'Ally Coalescence Efficiency, %', 'Enemy Coalescence Efficiency, %', 'Coalescence Kills / 10min', 'Objective Contest Time / 10min', 'Charge Kills / 10min', 'Fire Strike Kills / 10min', 'Earthshatter Kills / 10min', 'Long Range Kills / 10min', 'Storm Arrow Kills / 10min', 'Recon Assists / 10min', 'Dragonstrike Kills / 10min', 'Venom Mine Kills / 10min', 'Helix Rocket Accuracy, %', 'Helix Rocket Kills / 10min', 'Tactical Visor Kills / 10min', 'Charged Volley Accuracy, %', 'Charged Volley Kills / 10min', 'Transcendence Healing / 10min', 'Knockbacks / 10min', 'Sound Barriers / 10min', 'Micro Missile Kills, % / 10min', 'Call Mech Kills / 10min', 'Self-Destruct Kills / 10min', 'Direct Hits', 'Concussion Mine Kills / 10min', 'Enemies Trapped / 10min', 'Coach Gun Kills / 10min', 'Dynamite Kills / 10min', 'Bob Kills / 10min', 'Self Healing / 10min', 'Low Health Recalls / 10min', 'Pulse Bombs Stuck / 10min', 'Pulse Bomb Kills / 10min', 'Chain Hook Kills / 10min', 'Chain Hook Accuracy, %', 'Whole Hog Kills / 10min', 'Primary Accuracy, %', 'High Energy Kills / 10min', 'Average Energy, %', 'Graviton Surge Kills / 10min', 'Death Blossom Kills / 10min', 'Healing Accuracy', 'Deaths Prevented / 10min', 'Amp Matrix Assists / 10min', 'Energy Javelin Kills / 10min', 'Terra Surge Kills / 10min', 'Airtime, %', 'Barrage Kills / 10min', 'Accretion Kills / 10min', 'Overhealth / 10min', 'Gravitic Flux Kills / 10min', 'Rocket Punch Kills / 10min', 'Seismic Slam Kills / 10min', 'Meteor Strike Kills / 10min', 'Inspire Uptime', 'Icicle Accuracy, % / 10min', 'Icicle Crit Accuracy, % / 10min', 'Enemies Frozen / 10min', 'Blizzard Kills / 10min', 'Jump Pack Kills / 10min', 'Primal Rage Kills / 10min', 'Recon Kills / 10min', 'Assault Kills / 10min', 'Tactical Grenade Kills / 10min', 'Artillery Kills / 10min', 'Enemies Hacked / 10min', 'Low Health Teleports / 10min', 'EMP Kills / 10min', 'Grappling Claw Kills / 10min', 'Piledriver Kills / 10min', 'Charged Shot Accuracy, %', 'Charged Crit Accuracy, %', 'Charged Shot Kills / 10min', 'Disruptor Shot Kills / 10min', 'Overclock Kills / 10min', 'Average Damage Multiplier', 'Players Teleported / 10min', 'Sentry Turret Kills / 10min', 'Hammer Kills / 10min', 'Turret Kills / 10min', 'Molten Core Kills / 10min', 'Jagged Blade Accuracy, %', 'Carnage Kills / 10min', 'Wound Uptime, %', 'Rampage Kills / 10min', 'Focusing Beam Accuracy, %', 'Focusing Beam Kills / 10min', 'Sticky Bomb Accuracy, %', 'Sticky Bomb Kills / 10min', 'Duplicate Kills / 10min']

# %%
s1_data = s1_data.drop(columns=columns_to_drop)

# %%
s2_data = s2_data.drop(columns=columns_to_drop)

# %%
s3_data = s3_data.drop(columns=columns_to_drop)

# %%
s4_data = s4_data.drop(columns=columns_to_drop)

# %%
s1_data.head()
# Out:
#   Hero Skill Tier  KDA Ratio  Pick Rate, %  Win Rate, %  Eliminations / 10min  \
# 0  Ana        All       3.77          8.37        52.19                  8.86
# 1  Ana     Bronze       3.43          5.90        48.67                  7.89
# 2  Ana     Silver       3.30          5.94        43.95                  7.88
# 3  Ana       Gold       3.45          6.10        49.55                  8.39
# 4  Ana   Platinum       3.76         10.20        52.73                  8.57
#
#    Objective Kills / 10min  Objective Time / 10min  Damage / 10min  \
# 0                     4.06                      67            2400
# 1                     3.89                      64            2234
# 2                     3.74                      65            2258
# 3                     4.07                      64            2307
# 4                     3.99                      63            2321
#
#    Healing / 10min  Deaths / 10min  Scoped Accuracy, %     Role
# ...

# %%
s1_data.shape
# Out:
# (280, 13)

# %%
# New chracters were added in subsuquent seasons, whose abilities will be removed.
s2_columns_to_drop = ['Javelin Spin Kills / 10min', 'Pummel Accuracy, %', 'Pummel Kills / 10min', 'Ravenous Vortex Kills / 10min', 'Annihilation Kills / 10min']

# %%
s4_columns_to_drop = ['Life Grip Saves / 10min', 'Thorn Valley Kills / 10min']

# %%
s1_data.isna().sum()
# Out:
# Hero                         0
# Skill Tier                   0
# KDA Ratio                    0
# Pick Rate, %                 0
# Win Rate, %                  0
# Eliminations / 10min         0
# Objective Kills / 10min      0
# Objective Time / 10min       0
# Damage / 10min               0
# Healing / 10min            208
# Deaths / 10min               0
# Scoped Accuracy, %         256
# Role                         0
# dtype: int64

# %%
s2_data = s2_data.drop(columns=s2_columns_to_drop)

# %%
s2_data.isna().sum()
# Out:
# Hero                         0
# Skill Tier                   0
# KDA Ratio                    0
# Pick Rate, %                 0
# Win Rate, %                  0
# Eliminations / 10min         0
# Objective Kills / 10min      0
# Objective Time / 10min       0
# Damage / 10min               0
# Healing / 10min            216
# Deaths / 10min               0
# Scoped Accuracy, %         264
# Role                         0
# dtype: int64

# %%
s3_data = s3_data.drop(columns=s2_columns_to_drop)

# %%
s3_data.isna().sum()
# Out:
# Hero                         0
# Skill Tier                   0
# KDA Ratio                    0
# Pick Rate, %                 0
# Win Rate, %                  0
# Eliminations / 10min         0
# Objective Kills / 10min      0
# Objective Time / 10min       0
# Damage / 10min               0
# Healing / 10min            216
# Deaths / 10min               0
# Scoped Accuracy, %         264
# Role                         0
# dtype: int64

# %%
s4_data = s4_data.drop(columns=s2_columns_to_drop + s4_columns_to_drop)

# %%
s4_data.isna().sum()
# Out:
# Hero                         0
# Skill Tier                   0
# KDA Ratio                    0
# Pick Rate, %                 0
# Win Rate, %                  0
# Eliminations / 10min         0
# Objective Kills / 10min      0
# Objective Time / 10min       0
# Damage / 10min               0
# Healing / 10min            216
# Deaths / 10min               0
# Scoped Accuracy, %         272
# Role                         0
# dtype: int64

# %%
s4_data.duplicated().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 291    False
# 292    False
# 293    False
# 294    False
# 295    False
# Length: 296, dtype: bool>

# %%
s4_data.head()
# Out:
#   Hero Skill Tier  KDA Ratio  Pick Rate, %  Win Rate, %  Eliminations / 10min  \
# 0  Ana        All       4.23          9.57        49.30                  9.28
# 1  Ana     Bronze       3.93          3.74        44.70                  8.66
# 2  Ana     Silver       4.14          4.52        47.07                  8.99
# 3  Ana       Gold       4.21          6.51        48.72                  9.15
# 4  Ana   Platinum       4.31          9.68        48.97                  9.41
#
#    Objective Kills / 10min  Objective Time / 10min  Damage / 10min  \
# 0                     3.86                      62            2636
# 1                     3.86                      60            2586
# 2                     4.02                      63            2589
# 3                     4.02                      63            2578
# 4                     4.00                      63            2626
#
#    Healing / 10min  Deaths / 10min  Scoped Accuracy, %     Role
# ...

# %%
s1_data.to_csv('../data/s1_ow_cleaned.csv', index=False)
s2_data.to_csv('../data/s2_ow_cleaned.csv', index=False)
s3_data.to_csv('../data/s3_ow_cleaned.csv', index=False)
s4_data.to_csv('../data/s4_ow_cleaned.csv', index=False)
